# %% [markdown]
# <a href="https://colab.research.google.com/github/amryass/DRUG_Response-/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/drug200.csv')
df.head(5)
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB

# %%
df.isnull().sum()
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64

# %%
# Let's check the Target_feature , and as we see there is imblance data issue we have to solve first before fitting model on this data we have ; b
plt.figure(figsize = (6,3),dpi = 200)
sns.countplot(data = df , x = 'Drug')
# Out:
# <Axes: xlabel='Drug', ylabel='count'>

# %%
# Let's check the Target_feature , and as we see there is imblance data issue we have to solve first before fitting model on this data we have ; b
plt.figure(figsize = (6,3),dpi = 200)
sns.countplot(data = df , x = 'Drug')
# Out:
# <Axes: xlabel='Drug', ylabel='count'>

# %%
plt.figure(figsize = (10,6))
sns.barplot(x = 'Sex', y = 'Age', hue = 'Drug', data = df)
plt.title("CH vs NA_to_K")
plt.show()

# %%
drug_label = df['Drug'].value_counts().index
drug_label
# Out:
# Index(['DrugY', 'drugX', 'drugA', 'drugC', 'drugB'], dtype='object')

# %%
drug_count = df['Drug'].value_counts().tolist()

# %%
plt.figure(figsize = (8,4),dpi = 150)
plt.pie(drug_count , labels = drug_label , autopct = '%1.2f%%',textprops={'fontweight':'bold','size' :13},explode = [0.1,0,0,0,0],startangle= 90,
       pctdistance = 0.8 , radius = 2)
plt.show()

# %%
# Divid data to X and y , and also get dummies for all object data
X = pd.get_dummies(df.drop('Drug', axis = 1), drop_first= True ,prefix_sep = '*')
y = df['Drug']

# %%
from imblearn import over_sampling , under_sampling
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=0)
X_resambled , y_resampled = ros.fit_resample(X,y)

# %%
# Now we are going to make train test split to split the data we have to train data and test data
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resambled, y_resampled, test_size=0.20, random_state=101)

# %% [markdown]
# **KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score  , classification_report

# %%
pip install --upgrade scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Now we are going to make for loop to get the best K value :

test_error_rate = []

for k in range (1,30):
    knn_model = KNeighborsClassifier(n_neighbors=k)
    knn_model.fit(X_train , y_train)
    y_pred = knn_model.predict(X_test)

    test_error = 1 - accuracy_score(y_test , y_pred)
    test_error_rate.append(test_error)

# %%
plt.plot(range(1,30), test_error_rate)
plt.ylabel('Test_error_rate')
plt.xlabel('K Value')
plt.title('Get The Best K Value VS Test_error_Rate')
# Out:
# Text(0.5, 1.0, 'Get The Best K Value VS Test_error_Rate')

# %%
knn_model = KNeighborsClassifier(n_neighbors=1)
knn_model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
# Now lets diefine a function that will calculate needed metrics to avoid doing it on the upcoming algorithms D:
def metrics_needed (model):
    y_pred = model.predict(X_test)

    print('/n')

    print(classification_report(y_test,y_pred))

# %%
metrics_needed(knn_model)
# Out:
# /n
#               precision    recall  f1-score   support
#
#        DrugY       1.00      0.80      0.89        20
#        drugA       0.91      1.00      0.95        21
#        drugB       0.94      1.00      0.97        17
#        drugC       1.00      1.00      1.00        16
#        drugX       0.94      1.00      0.97        17
#
#     accuracy                           0.96        91
#    macro avg       0.96      0.96      0.96        91
# weighted avg       0.96      0.96      0.95        91

# %% [markdown]
# # Decision_Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree_model = DecisionTreeClassifier()

# %%
tree_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
metrics_needed(tree_model)
# Out:
# /n
#               precision    recall  f1-score   support
#
#        DrugY       1.00      1.00      1.00        20
#        drugA       1.00      1.00      1.00        21
#        drugB       1.00      1.00      1.00        17
#        drugC       1.00      1.00      1.00        16
#        drugX       1.00      1.00      1.00        17
#
#     accuracy                           1.00        91
#    macro avg       1.00      1.00      1.00        91
# weighted avg       1.00      1.00      1.00        91

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
random_model = RandomForestClassifier(n_estimators=10 , max_features='auto',random_state=101)
#Here, n_estimators specifies the number of trees in the random forest, max_features specifies the number of features to consider at each split, and random_state is the random seed used to ensure reproducibility of the results.

# %%
random_model.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# RandomForestClassifier(max_features='auto', n_estimators=10, random_state=101)

# %%
metrics_needed(random_model)
# Out:
# /n
#               precision    recall  f1-score   support
#
#        DrugY       1.00      0.95      0.97        20
#        drugA       1.00      1.00      1.00        21
#        drugB       1.00      1.00      1.00        17
#        drugC       1.00      1.00      1.00        16
#        drugX       0.94      1.00      0.97        17
#
#     accuracy                           0.99        91
#    macro avg       0.99      0.99      0.99        91
# weighted avg       0.99      0.99      0.99        91
